# %% [markdown]
# - Kevin Ridge

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
main_url = "https://datasets.imdbws.com/"

basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
        
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"
            
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# 1) Filtering/Cleaning Steps:
# 2) Title Basics:
# - Replace "\N" with np.nan
# - Eliminate movies that are null for runtimeMinutes
# - Eliminate movies that are null for genre
# - keep only titleType==Movie
# - keep startYear 2000-2022
# - Eliminate movies that include "Documentary" in genre (see tip below)
# - Keep only US movies (Use AKAs table, see "Filtering one dataframe based on another" section below)
#
# - After searching, I am not sure how to do the 'keep only' parts of this project...

# %%
# Replace "\N" with np.nan
basics.replace({'\\N':np.nan}, inplace=True)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
# Eliminate movies that are null for runtimeMinutes, and genres
basics.dropna(subset=['runtimeMinutes','genres'], inplace=True)

# %%
# keep only titleType==Movie
df_bas = basics[basics['titleType']=='movie']
df_bas.head()
# Out:
#         tconst titleType                    primaryTitle  \
# 8    tt0000009     movie                      Miss Jerry
# 144  tt0000147     movie   The Corbett-Fitzsimmons Fight
# 570  tt0000574     movie     The Story of the Kelly Gang
# 587  tt0000591     movie                The Prodigal Son
# 672  tt0000679     movie  The Fairylogue and Radio-Plays
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 8                        Miss Jerry       0      1894     NaN             45
# 144   The Corbett-Fitzsimmons Fight       0      1897     NaN            100
# 570     The Story of the Kelly Gang       0      1906     NaN             70
# 587               L'enfant prodigue       0      1907     NaN             90
# 672  The Fairylogue and Radio-Plays       0      1908     NaN            120
#
#                          genres
# 8                       Romance
# 144      Documentary,News,Sport
# 570  Action,Adventure,Biography
# 587                       Drama
# 672           Adventure,Fantasy

# %%
df_bas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 384349 entries, 8 to 9961489
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          384349 non-null  object
#  1   titleType       384349 non-null  object
#  2   primaryTitle    384349 non-null  object
#  3   originalTitle   384349 non-null  object
#  4   isAdult         384349 non-null  object
#  5   startYear       377836 non-null  object
#  6   endYear         0 non-null       object
#  7   runtimeMinutes  384349 non-null  object
#  8   genres          384349 non-null  object
# dtypes: object(9)
# memory usage: 29.3+ MB

# %%
# Check for Nan's
df_bas.isna().sum()
# Out:
# tconst                 0
# titleType              0
# primaryTitle           0
# originalTitle          0
# isAdult                0
# startYear           6513
# endYear           384349
# runtimeMinutes         0
# genres                 0
# dtype: int64

# %%
# drop the NaN's so filter can be used
df_bas.dropna(subset = ['startYear'], inplace=True)
# Out:
# C:\Users\ridge\AppData\Local\Temp\ipykernel_25040\4136044397.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bas.dropna(subset = ['startYear'], inplace=True)

# %%
# Change startYear datatype to integer so filter can be used
df_bas['startYear'] = df_bas['startYear'].astype(int)
# Out:
# C:\Users\ridge\AppData\Local\Temp\ipykernel_25040\1883128771.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bas['startYear'] = df_bas['startYear'].astype(int)

# %%
# Keep only movies with startYear 2000-2022
df_bas = df_bas.loc[(df_bas['startYear']>=2000)&(df_bas['startYear']<=2022)]

# %%
df_bas['startYear'].value_counts()
# Out:
# 2017    14388
# 2018    14358
# 2019    14112
# 2016    13974
# 2015    13483
# 2014    13126
# 2022    12961
# 2021    12433
# 2013    12397
# 2012    11655
# 2020    11601
# 2011    10783
# 2010    10216
# 2009     9372
# 2008     8167
# 2007     6972
# 2006     6528
# 2005     5851
# 2004     5219
# 2003     4601
# 2002     4140
# 2001     3878
# 2000     3646
# Name: startYear, dtype: int64

# %%
# Create object data type variable
dtypes = df_bas.dtypes
typ_obj = dtypes[dtypes== 'object'].index
typ_obj
# Out:
# Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'endYear', 'runtimeMinutes', 'genres'],
#       dtype='object')

# %%
# Inspect the object data types
for col in typ_obj:
  print(f'-Column= {col}')
  print(df_bas[col].value_counts(dropna=False))
  print('\n')
# Out:
# -Column= tconst
# tt0013274     1
# tt3397838     1
# tt3397096     1
# tt3397146     1
# tt3397160     1
#              ..
# tt14572568    1
# tt14572596    1
# tt14573620    1
# tt14573918    1
# tt9916754     1
# Name: tconst, Length: 223861, dtype: int64
#
#
# -Column= titleType
# movie    223861
# Name: titleType, dtype: int64
#
#
# -Column= primaryTitle
# Home                              31
# Broken                            26
# Alone                             24
# Metamorphosis                     23
# Homecoming                        21
#                                   ..
# Ghosts of the 7th Cavalry          1
# The Unseen Side of Aphrodite       1
# The Well Digger's Daughter         1
# Zone Drifter                       1
# Chico Albuquerque - Revelações     1
# Name: primaryTitle, Length: 203965, dtype: int64
#
#
# -Column= originalTitle
# Home                              26
# Broken                            25
# Alone                             19
# Run                               19
# Solo                              16
#                                   ..
# Sennai                             1
# A ojos cerrados                    1
# Breath of Fresh Air                1
# Cigarettes for Breakfast           1
# Chico Albuquerque - Revelações     1
# Name: originalTitle, Length: 208930, dtype: int64
#
#
# -Column= isAdult
# 0    223023
# 1       838
# Name: isAdult, dtype: int64
#
#
# -Column= endYear
# NaN    223861
# Name: endYear, dtype: int64
#
#
# -Column= runtimeMinutes
# 90     14322
# 80      6581
# 85      5676
# 100     5427
# 95      5371
#        ...
# 328        1
# 641        1
# 339        1
# 960        1
# 808        1
# Name: runtimeMinutes, Length: 445, dtype: int64
#
#
# -Column= genres
# Documentary                   53430
# Drama                         36107
# Comedy                        13469
# Comedy,Drama                   6458
# Horror                         5812
#                               ...
# Adventure,Romance,Sport           1
# Action,Music,Sci-Fi               1
# Biography,Comedy,War              1
# Adventure,History,Thriller        1
# Crime,Fantasy,Sci-Fi              1
# Name: genres, Length: 1172, dtype: int64

# %%
# Exclude movies that are included in the documentary category.
is_documentary = df_bas['genres'].str.contains('documentary',case=False)
df_bas2 = df_bas[~is_documentary]

# %%
df_bas2['genres'].value_counts()
# Out:
# Drama                       36107
# Comedy                      13469
# Comedy,Drama                 6458
# Horror                       5812
# Drama,Romance                4319
#                             ...
# Adult,Biography,Drama           1
# Crime,Family,Mystery            1
# Crime,Horror,Western            1
# Adventure,Horror,Musical        1
# Crime,Fantasy,Sci-Fi            1
# Name: genres, Length: 955, dtype: int64

# %% [markdown]
# # AKA dataset cleaning

# %%
# Display title akas info
akas.info()
akas.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36370992 entries, 0 to 36370991
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.2+ GB
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
# Replace "\N" with np.nan
akas.replace({'\\N': np.nan}, inplace=True)

# %%
# Keep only the movies from US region
us_df = akas[akas['region']=='US']

# %%
us_df.head(20)
# Out:
#        titleId  ordering                                              title  \
# 5    tt0000001         6                                         Carmencita
# 14   tt0000002         7                             The Clown and His Dogs
# 33   tt0000005        10                                   Blacksmith Scene
# 36   tt0000005         1                                Blacksmithing Scene
# 41   tt0000005         6                                Blacksmith Scene #1
# 42   tt0000005         7                                      Blacksmithing
# 47   tt0000006         3                                  Chinese Opium Den
# 52   tt0000007         1        Corbett and Courtney Before the Kinetograph
# 56   tt0000007         5                         The Corbett-Courtney Fight
# 57   tt0000007         6                     Jim Corbett vs. Peter Courtney
# 65   tt0000008         3  Edison Kinetoscopic Record of a Sneeze, Januar...
# 66   tt0000008         4             Edison Kinetoscopic Record of a Sneeze
# 70   tt0000008         8  The Films of Thomas A Edison presented by Raym...
# 76   tt0000009         5                                         Miss Jerry
# 83   tt0000010        16                                Exiting the Factory
# 89   tt0000010        21                                Leaving the Factory
# 95   tt0000010         3              Employees Leaving the Lumière Factory
# 100  tt0000010         8                Workers Leaving the Lumière Factory
# 115  tt0000012         1                             The Arrival of a Train
# 126  tt0000012         3                      The Arrival of the Mail Train
#
#     region language        types                  attributes isOriginalTitle
# 5       US      NaN  imdbDisplay                         NaN               0
# 14      US      NaN          NaN       literal English title               0
# 33      US      NaN  imdbDisplay                         NaN               0
# 36      US      NaN  alternative                         NaN               0
# 41      US      NaN  alternative                         NaN               0
# 42      US      NaN          NaN  informal alternative title               0
# 47      US      NaN  imdbDisplay                         NaN               0
# 52      US      NaN  imdbDisplay                         NaN               0
# 56      US      NaN  alternative                         NaN               0
# 57      US      NaN  alternative                         NaN               0
# 65      US      NaN          NaN              complete title               0
# 66      US      NaN  imdbDisplay                         NaN               0
# 70      US      NaN          NaN               reissue title               0
# 76      US      NaN  imdbDisplay                         NaN               0
# 83      US      NaN  imdbDisplay                         NaN               0
# 89      US      NaN  imdbDisplay                         NaN               0
# 95      US      NaN  alternative                         NaN               0
# 100     US      NaN  imdbDisplay                         NaN               0
# 115     US      NaN  imdbDisplay                         NaN               0
# 126     US      NaN  alternative                         NaN               0

# %%
# Filter the basics table down to only include the US by using the filter akas
#dataframe
keepers = df_bas2['tconst'].isin(us_df['titleId'])
keepers
# Out:
# 34803       True
# 42384       True
# 61115       True
# 67667       True
# 86799       True
#            ...
# 9961212     True
# 9961221     True
# 9961260    False
# 9961305     True
# 9961389    False
# Name: tconst, Length: 147799, dtype: bool

# %%
# Display the filtered data
df_bas3 = df_bas2[keepers]
df_bas3
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 42384    tt0043139     movie
# 61115    tt0062336     movie
# 67667    tt0069049     movie
# 86799    tt0088751     movie
# ...            ...       ...
# 9960677  tt9914942     movie
# 9961072  tt9915872     movie
# 9961212  tt9916170     movie
# 9961221  tt9916190     movie
# 9961305  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 42384                          Life of a Beijing Policeman
# 61115    The Tango of the Widower and Its Distorting Mi...
# 67667                           The Other Side of the Wind
# 86799                                    The Naked Monster
# ...                                                    ...
# 9960677                             Life Without Sara Amat
# 9961072                               The Last White Witch
# 9961212                                      The Rehearsal
# 9961221                                          Safeguard
# 9961305                                              Coven
#
#                                      originalTitle isAdult  startYear endYear  \
# 34803                               Kate & Leopold       0       2001     NaN
# 42384                             Wo zhe yi bei zi       0       2013     NaN
# 61115    El tango del viudo y su espejo deformante       0       2020     NaN
# 67667                   The Other Side of the Wind       0       2018     NaN
# 86799                            The Naked Monster       0       2005     NaN
# ...                                            ...     ...        ...     ...
# 9960677                 La vida sense la Sara Amat       0       2019     NaN
# 9961072                  My Girlfriend is a Wizard       0       2019     NaN
# 9961212                                   O Ensaio       0       2019     NaN
# 9961221                                  Safeguard       0       2020     NaN
# 9961305                                   Akelarre       0       2020     NaN
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 42384              120              Drama,History
# 61115               70                      Drama
# 67667              122                      Drama
# 86799              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9960677             74                      Drama
# 9961072             97       Comedy,Drama,Fantasy
# 9961212             51                      Drama
# 9961221             95  Action,Adventure,Thriller
# 9961305             92              Drama,History
#
# [86844 rows x 9 columns]

# %% [markdown]
# # Ratings dataset cleaning

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1323907 entries, 0 to 1323906
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1323907 non-null  object
#  1   averageRating  1323907 non-null  float64
#  2   numVotes       1323907 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 30.3+ MB

# %%
# Replace "\N" with np.nan (if any)
ratings.replace({'\\N': np.nan}, inplace=True)

# %%
# Keep only US movies 
ratings2 = ratings['tconst'].isin(us_df['titleId'])
ratings2
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1323902    False
# 1323903    False
# 1323904    False
# 1323905    False
# 1323906    False
# Name: tconst, Length: 1323907, dtype: bool

# %%
ratings2.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1323907 entries, 0 to 1323906
# Series name: tconst
# Non-Null Count    Dtype
# --------------    -----
# 1323907 non-null  bool
# dtypes: bool(1)
# memory usage: 1.3 MB

# %%
# Display the filtered data
ratings2 = ratings[ratings2]
ratings2
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1982
# 1        tt0000002            5.8       265
# 4        tt0000005            6.2      2625
# 5        tt0000006            5.1       182
# 6        tt0000007            5.4       820
# ...            ...            ...       ...
# 1323868  tt9916200            8.1       230
# 1323869  tt9916204            8.2       263
# 1323876  tt9916348            8.3        18
# 1323877  tt9916362            6.4      5390
# 1323882  tt9916428            3.8        14
#
# [502123 rows x 3 columns]

# %%
akas.to_csv('Data/title_akas_cleaned.csv.gz',compression='gzip',index=False)

# %%
#df_bas1['genres'].value_counts()

# %%
# Eliminate movies that include "Documentary" in genre
#df_bas1 = df_bas[~df_bas['genres'].isin(['Documentary'])]
